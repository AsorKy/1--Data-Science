# %% [markdown]
# #1)-Introduction to Python with Google Colab - 1

# %% [markdown]
# In the following notebook we are going to see the basic concepts of Python such as:
#
#
#
# 1.   Terminal commands
# 2.   Packages and Pip
# 3.   Files manager
# 4.   Google Drive
# 5.   Algebraic Operators
# 6.   Variables and data types
# 7.   Logic and comparison Operators
# 8.   Loops and iterators
# 9.   Functions
# 10.   Data structures

# %% [markdown]
# #2)-Terminal Commands

# %% [markdown]
# To excecute a cell: control + enter
#
# To go to Jupyter pannel: control + shift +p

# %% [markdown]
# 2.1)- To print the directory rute: pwd - Print Working Directory

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# 2.2)- List the elements within a folder

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# 2.3)- cd - change directory

# %%
# !cd sample_data

# %% [markdown]
# 2.4)- cat / touch- Open a file

# %%
# !cat anscombe.json

# %%
# !touch ejemplo.txt

# %% [markdown]
# #4)-Google Drive
